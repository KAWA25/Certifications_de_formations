# %% [markdown]
# <a href="https://colab.research.google.com/github/KAWA25/Certifications_de_formations/blob/main/Analyse_donn%C3%A9es_pays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercice Partie 1 : Analysez des données de systèmes éducatifs

# %% [markdown]
# Etape 1 : chargement des données dans Google Colab:
#
# ----Résultats attendus
#
# ----Avoir chargé les données.
#
# ----Visualiser dans un Jupyter Notebook les premières lignes des cinq fichiers
#
# ----en utilisant Pandas (présenté dans le cours ci-dessus).

# %%
#1-  chargement des données Country

import pandas as pd
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-9c13e5b4-c05e-4f13-a81f-364178de45d6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c13e5b4-c05e-4f13-a81f-364178de45d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#2-  chargement des données Country Séries

import pandas as pd
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-088a413b-5038-4c6d-b666-adc5897ba9f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-088a413b-5038-4c6d-b666-adc5897ba9f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#3-  chargement des données Data

import pandas as pd
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-7a5ddae4-66a7-4c82-b103-bd2804747ddc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a5ddae4-66a7-4c82-b103-bd2804747ddc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#4  chargement des données Foot Note

import pandas as pd
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-146c3e2b-8e1b-4142-8271-5d23e18ac141" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-146c3e2b-8e1b-4142-8271-5d23e18ac141">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#5-  chargement des données Séries

import pandas as pd
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-7f11ab38-9ce9-4396-97be-282bb338848d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f11ab38-9ce9-4396-97be-282bb338848d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# -----------------------------------------------------------------------------------

# %% [markdown]
# Visualisation des premières lignes des 5 fichiers

# %% [markdown]
# --------------------------------------------------------------------------------------

# %%
#1----lire le fichier Country

df_country = pd.read_csv('EdStatsCountry.csv')
df_country.head(4)
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
#
#                       Region          Income Group WB-2 code  ...  \
# 0  Latin America & Caribbean  High income: nonOECD        AW  ...
# ...

# %%
#2----lire le fichier Country Séries

df_countrySeries = pd.read_csv('EdStatsCountry-Series.csv')
df_countrySeries.head(4)
# Out:
#   CountryCode         SeriesCode  \
# 0         ABW        SP.POP.TOTL
# 1         ABW        SP.POP.GROW
# 2         AFG        SP.POP.GROW
# 3         AFG  NY.GDP.PCAP.PP.CD
#
#                                          DESCRIPTION  Unnamed: 3
# 0  Data sources : United Nations World Population...         NaN
# 1  Data sources: United Nations World Population ...         NaN
# 2  Data sources: United Nations World Population ...         NaN
# 3                 Estimates are based on regression.         NaN

# %%
#3----lire le fichier Data

df_data = pd.read_csv('EdStatsData.csv')
df_data.head(4)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  1970  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2   NaN
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F   NaN
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI   NaN
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M   NaN
#
#    1971  1972  1973  1974  1975  ...  2060  2065  2070  2075  2080  2085  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2090  2095  2100  Unnamed: 69
# 0   NaN   NaN   NaN          NaN
# ...

# %%
#4----lire le fichier Foot Note

df_FootNote = pd.read_csv('EdStatsFootNote.csv')
df_FootNote.head(4)
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN

# %%
#5-----lire le fichier Séries

df_Series = pd.read_csv('EdStatsSeries.csv')
df_Series.head(4)
# Out:
#            Series Code       Topic  \
# 0  BAR.NOED.1519.FE.ZS  Attainment
# 1     BAR.NOED.1519.ZS  Attainment
# 2  BAR.NOED.15UP.FE.ZS  Attainment
# 3     BAR.NOED.15UP.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
#
#                                     Short definition  \
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
#
#                                      Long definition  Unit of measure  \
# 0  Percentage of female population age 15-19 with...              NaN
# 1  Percentage of population age 15-19 with no edu...              NaN
# ...

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# Etape 2 : Collecter les informations basiques sur chaque jeu de données

# %% [markdown]
# ----------------------------------------------------------------------

# %% [markdown]
# -------Fichier Séries--------------

# %%
# Nombre de lignes et de colonnes de la table series

nb_lignes, nb_colonnes = df_Series.shape
print("Nombre de lignes :", nb_lignes)
print("Nombre de colonnes :", nb_colonnes)
# Out:
# Nombre de lignes : 3665
# Nombre de colonnes : 21

# %%
# Nombre de lignes dupliquées de la table series

nb_doublons = df_Series.duplicated().sum()
print("Nombre de doublons :", nb_doublons)
# Out:
# Nombre de doublons : 0

# %%
# Proportion de valeurs manquantes par colonne de la table series

proportion_manquantes = df_Series.isna().mean()
print(proportion_manquantes)
# Out:
# Series Code                            0.000000
# Topic                                  0.000000
# Indicator Name                         0.000000
# Short definition                       0.411733
# Long definition                        0.000000
# Unit of measure                        1.000000
# Periodicity                            0.972988
# Base Period                            0.914325
# Other notes                            0.849386
# Aggregation method                     0.987176
# Limitations and exceptions             0.996180
# Notes from original source             1.000000
# General comments                       0.996180
# Source                                 0.000000
# Statistical concept and methodology    0.993724
# Development relevance                  0.999181
# Related source links                   0.941337
# Other web links                        1.000000
# Related indicators                     1.000000
# License Type                           1.000000
# ...

# %%
# Statistiques descriptives de la table Serie

stats = df_Series.describe()
print(stats)
# Out:
#        Unit of measure  Notes from original source  Other web links  \
# count              0.0                         0.0              0.0
# mean               NaN                         NaN              NaN
# std                NaN                         NaN              NaN
# min                NaN                         NaN              NaN
# 25%                NaN                         NaN              NaN
# 50%                NaN                         NaN              NaN
# 75%                NaN                         NaN              NaN
# max                NaN                         NaN              NaN
#
#        Related indicators  License Type  Unnamed: 20
# count                 0.0           0.0          0.0
# mean                  NaN           NaN          NaN
# std                   NaN           NaN          NaN
# min                   NaN           NaN          NaN
# 25%                   NaN           NaN          NaN
# ...

# %%
# Nombre d'occurrences par valeur de la table serie

occurrences = df_Series['Topic'].value_counts()
print(occurrences)
# Out:
# Topic
# Learning Outcomes                                                                               1046
# Attainment                                                                                       733
# Education Equality                                                                               426
# Secondary                                                                                        256
# Primary                                                                                          248
# Population                                                                                       213
# Tertiary                                                                                         158
# Teachers                                                                                         137
# Expenditures                                                                                      93
# ...

# %% [markdown]
# ------------Fin fichier Séries--------------

# %% [markdown]
# -----------Fichier Country-----------------

# %%
# Nombre de lignes et de colonnes de la table Country

nb_lignes, nb_colonnes = df_country.shape
print("Nombre de lignes :", nb_lignes)
print("Nombre de colonnes :", nb_colonnes)
# Out:
# Nombre de lignes : 241
# Nombre de colonnes : 32

# %%
# Nombre de lignes dupliquées de la tables country
nb_doublons = df_country.duplicated().sum()
print("Nombre de doublons :", nb_doublons)
# Out:
# Nombre de doublons : 0

# %%
# Proportion de valeurs manquantes par colonne de la table country
proportion_manquantes = df_country.isna().mean()
print(proportion_manquantes)
# Out:
# Country Code                                         0.000000
# Short Name                                           0.000000
# Table Name                                           0.000000
# Long Name                                            0.000000
# 2-alpha code                                         0.012448
# Currency Unit                                        0.107884
# Special Notes                                        0.398340
# Region                                               0.112033
# Income Group                                         0.112033
# WB-2 code                                            0.004149
# National accounts base year                          0.149378
# National accounts reference year                     0.867220
# SNA price valuation                                  0.182573
# Lending category                                     0.402490
# Other groups                                         0.759336
# ...

# %%
# Statistiques descriptives de la table country
stats = df_country.describe()
print(stats)
# Out:
#        National accounts reference year  Latest industrial data  \
# count                          32.00000              107.000000
# mean                         2001.53125             2008.102804
# std                             5.24856                2.616834
# min                          1987.00000             2000.000000
# 25%                          1996.75000             2007.500000
# 50%                          2002.00000             2009.000000
# 75%                          2005.00000             2010.000000
# max                          2012.00000             2010.000000
#
#        Latest trade data  Unnamed: 31
# count         185.000000          0.0
# mean         2010.994595          NaN
# std             2.569675          NaN
# min          1995.000000          NaN
# 25%          2011.000000          NaN
# 50%          2012.000000          NaN
# 75%          2012.000000          NaN
# max          2012.000000          NaN

# %%
# Nombre d'occurrences par valeur de la table country

occurrences = df_country['Region'].value_counts()
print(occurrences)
# Out:
# Region
# Europe & Central Asia         57
# Sub-Saharan Africa            48
# Latin America & Caribbean     41
# East Asia & Pacific           36
# Middle East & North Africa    21
# South Asia                     8
# North America                  3
# Name: count, dtype: int64

# %% [markdown]
# -------------Fin fichier Country------

# %% [markdown]
# ---------Fichier Foot Note-------------

# %%
# Nombre de lignes et de colonnes du fichier Foot Note

nb_lignes, nb_colonnes = df_FootNote.shape
print("Nombre de lignes :", nb_lignes)
print("Nombre de colonnes :", nb_colonnes)
# Out:
# Nombre de lignes : 643638
# Nombre de colonnes : 5

# %%
# Nombre de lignes dupliquées du fichier Foot Note

nb_doublons = df_FootNote.duplicated().sum()
print("Nombre de doublons :", nb_doublons)
# Out:
# Nombre de doublons : 0

# %%
# Proportion de valeurs manquantes par colonne du fichier Foot Note

proportion_manquantes = df_country.isna().mean()
print(proportion_manquantes)
# Out:
# Country Code                                         0.000000
# Short Name                                           0.000000
# Table Name                                           0.000000
# Long Name                                            0.000000
# 2-alpha code                                         0.012448
# Currency Unit                                        0.107884
# Special Notes                                        0.398340
# Region                                               0.112033
# Income Group                                         0.112033
# WB-2 code                                            0.004149
# National accounts base year                          0.149378
# National accounts reference year                     0.867220
# SNA price valuation                                  0.182573
# Lending category                                     0.402490
# Other groups                                         0.759336
# ...

# %%
# Statistiques descriptives du Fichier Foot Note

stats = df_FootNote.describe()
print(stats)
# Out:
#        Unnamed: 4
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# Nombre d'occurrences par valeur du Fichier Foot Note

occurrences = df_FootNote['Year'].value_counts()
print(occurrences)
# Out:
# Year
# YR2004    27128
# YR2005    25992
# YR2002    25687
# YR2003    25683
# YR2000    25093
# YR2001    25047
# YR2008    25018
# YR1999    24938
# YR2007    24263
# YR2006    23394
# YR2009    22965
# YR2010    22598
# YR2011    17760
# YR1998    14916
# YR2012    13890
# YR2013    13405
# YR1994    11448
# YR2014    11378
# YR1992    11309
# YR1996    11197
# YR1995    11194
# YR1997    11167
# YR1991    11129
# YR1993    11093
# YR1990    10616
# YR1986     9743
# YR1985     9653
# YR1989     9517
# YR1981     9465
# YR1984     9386
# YR1988     9382
# YR1987     9357
# YR1983     9227
# YR1982     9014
# YR1980     8950
# YR1979     8742
# YR1976     8729
# YR1972     8661
# YR1975     8627
# YR1977     8593
# YR1978     8585
# YR1973     8571
# YR1974     8512
# YR1971     8507
# YR2015     6348
# YR1970     5374
# YR2016      819
# YR2017      558
# YR2035      144
# YR2050      144
# YR2045      144
# YR2040      144
# YR2030      140
# YR2025      140
# YR2020      140
# ...

# %% [markdown]
# --------------Fin fichier Foot Note--------------

# %% [markdown]
# ---------------Fichier Data-------------------

# %%
# Nombre de lignes et de colonnes du fichier Data

nb_lignes, nb_colonnes = df_data.shape
print("Nombre de lignes :", nb_lignes)
print("Nombre de colonnes :", nb_colonnes)
# Out:
# Nombre de lignes : 886930
# Nombre de colonnes : 70

# %%
# Nombre de lignes dupliquées du fichier Data
nb_doublons = df_data.duplicated().sum()
print("Nombre de doublons :", nb_doublons)
# Out:
# Nombre de doublons : 0

# %%
# Proportion de valeurs manquantes par colonne du fichier Data

proportion_manquantes = df_data.isna().mean()
print(proportion_manquantes)
# Out:
# Country Name      0.000000
# Country Code      0.000000
# Indicator Name    0.000000
# Indicator Code    0.000000
# 1970              0.918496
#                     ...
# 2085              0.942007
# 2090              0.942007
# 2095              0.942007
# 2100              0.942007
# Unnamed: 69       1.000000
# Length: 70, dtype: float64

# %%
# Statistiques descriptives du Fichier Data

stats = df_data.describe()
print(stats)
# Out:
#                1970          1971          1972          1973          1974  \
# count  7.228800e+04  3.553700e+04  3.561900e+04  3.554500e+04  3.573000e+04
# mean   1.974772e+09  4.253638e+09  4.592365e+09  5.105006e+09  5.401493e+09
# std    1.211687e+11  1.804814e+11  1.914083e+11  2.059170e+11  2.112150e+11
# min   -1.435564e+00 -1.594625e+00 -3.056522e+00 -4.032582e+00 -4.213563e+00
# 25%    8.900000e-01  8.853210e+00  9.240920e+00  9.595200e+00  9.861595e+00
# 50%    6.317724e+00  6.316240e+01  6.655139e+01  6.969595e+01  7.087760e+01
# 75%    6.251250e+01  5.655200e+04  5.863650e+04  6.202900e+04  6.383675e+04
# max    1.903929e+13  1.986457e+13  2.100916e+13  2.238367e+13  2.282991e+13
#
#                1975          1976          1977          1978          1979  \
# count  8.730600e+04  3.748300e+04  3.757400e+04  3.757600e+04  3.680900e+04
# mean   2.314288e+09  5.731808e+09  6.124437e+09  6.671489e+09  7.436724e+09
# ...

# %%
# Nombre d'occurrences par valeur du Fichier Data

occurrences = df_data['Country Code'].value_counts()
print(occurrences)
# Out:
# Country Code
# ARB    3665
# EAS    3665
# EAP    3665
# EMU    3665
# ECS    3665
#        ...
# VIR    3665
# PSE    3665
# YEM    3665
# ZMB    3665
# ZWE    3665
# Name: count, Length: 242, dtype: int64

# %% [markdown]
# ---------------Fin du fichier Data---------------------

# %% [markdown]
# -----------Fichier Country Séries----------------

# %%
# Nombre de lignes et de colonnes du fichier Country Séries

nb_lignes, nb_colonnes = df_countrySeries.shape
print("Nombre de lignes :", nb_lignes)
print("Nombre de colonnes :", nb_colonnes)
# Out:
# Nombre de lignes : 613
# Nombre de colonnes : 4

# %%
# Nombre de lignes dupliquées du fichier Country Séries

nb_doublons = df_countrySeries.duplicated().sum()
print("Nombre de doublons :", nb_doublons)
# Out:
# Nombre de doublons : 0

# %%
# Proportion de valeurs manquantes par colonne du fichier Country Séries

proportion_manquantes = df_countrySeries.isna().mean()
print(proportion_manquantes)
# Out:
# CountryCode    0.0
# SeriesCode     0.0
# DESCRIPTION    0.0
# Unnamed: 3     1.0
# dtype: float64

# %%
# Statistiques descriptives du Fichier Country Séries

stats = df_countrySeries.describe()
print(stats)
# Out:
#        Unnamed: 3
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# Nombre d'occurrences par valeur du Fichier Country Séries

occurrences = df_countrySeries['SeriesCode'].value_counts()
print(occurrences)
# Out:
# SeriesCode
# SP.POP.TOTL          211
# SP.POP.GROW          211
# NY.GDP.PCAP.PP.CD     19
# NY.GNP.PCAP.PP.CD     19
# NY.GDP.PCAP.PP.KD     19
# NY.GNP.MKTP.PP.CD     14
# NY.GDP.MKTP.PP.KD     14
# NY.GDP.MKTP.PP.CD     14
# SP.POP.1564.TO.ZS     13
# SP.POP.TOTL.MA.ZS     13
# SP.POP.TOTL.FE.ZS     13
# SP.POP.0014.TO.ZS     13
# NY.GNP.PCAP.CD         6
# NY.GDP.PCAP.CD         5
# NY.GDP.PCAP.KD         5
# SP.POP.1564.MA.IN      4
# SP.POP.0014.TO         4
# SP.POP.1564.TO         4
# SP.POP.1564.FE.IN      4
# SP.POP.0014.MA.IN      4
# SP.POP.0014.FE.IN      4
# Name: count, dtype: int64

# %% [markdown]
# -------------------Fin du fichier Country Séries---------------

# %% [markdown]
# --------------------------------------------------------------------------

# %% [markdown]
# Etape 3 : Réaliser votre premier Nettoyage

# %% [markdown]
# ------

# %% [markdown]
# Résultat attendu
#
# -----------Filtrer les faux pays des tables où cela fait sens (Country, Country-Series, FootNote et Data).

# %% [markdown]
# ------------Filtrage des faux pays dans le Fichier Country-----------

# %%
df_country["Short Name"].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'The Bahamas',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland',
#        'Channel Islands', 'Chile', 'China', "Côte d'Ivoire", 'Cameroon',
#        'Dem. Rep. Congo', 'Congo', 'Colombia', 'Comoros', 'Cabo Verde',
#        'Costa Rica', 'Cuba', 'Curaçao', 'Cayman Islands', 'Cyprus',
#        'Czech Republic', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
#        'Dominican Republic', 'Algeria',
#        'East Asia & Pacific (developing only)',
#        'East Asia & Pacific (all income levels)',
# ...

# %%
df_country[["Short Name","Region"]]
# Out:
#        Short Name                      Region
# 0           Aruba   Latin America & Caribbean
# 1     Afghanistan                  South Asia
# 2          Angola          Sub-Saharan Africa
# 3         Albania       Europe & Central Asia
# 4         Andorra       Europe & Central Asia
# ..            ...                         ...
# 236        Kosovo       Europe & Central Asia
# 237         Yemen  Middle East & North Africa
# 238  South Africa          Sub-Saharan Africa
# 239        Zambia          Sub-Saharan Africa
# 240      Zimbabwe          Sub-Saharan Africa
#
# [241 rows x 2 columns]

# %%
#Nettoyage de la table country

country_to_remove=df_country[df_country["Region"].isna()]["Country Code"]
country_to_remove
df_country[~df_country["Country Code"].isin(country_to_remove)]
# Out:
#     Country Code    Short Name    Table Name                     Long Name  \
# 0            ABW         Aruba         Aruba                         Aruba
# 1            AFG   Afghanistan   Afghanistan  Islamic State of Afghanistan
# 2            AGO        Angola        Angola   People's Republic of Angola
# 3            ALB       Albania       Albania           Republic of Albania
# 4            AND       Andorra       Andorra       Principality of Andorra
# ..           ...           ...           ...                           ...
# 236          XKX        Kosovo        Kosovo            Republic of Kosovo
# 237          YEM         Yemen   Yemen, Rep.             Republic of Yemen
# 238          ZAF  South Africa  South Africa      Republic of South Africa
# 239          ZMB        Zambia        Zambia            Republic of Zambia
# 240          ZWE      Zimbabwe      Zimbabwe          Republic of Zimbabwe
#
#     2-alpha code       Currency Unit  \
# ...

# %%
df_country[["Short Name","Region"]]
# Out:
#        Short Name                      Region
# 0           Aruba   Latin America & Caribbean
# 1     Afghanistan                  South Asia
# 2          Angola          Sub-Saharan Africa
# 3         Albania       Europe & Central Asia
# 4         Andorra       Europe & Central Asia
# ..            ...                         ...
# 236        Kosovo       Europe & Central Asia
# 237         Yemen  Middle East & North Africa
# 238  South Africa          Sub-Saharan Africa
# 239        Zambia          Sub-Saharan Africa
# 240      Zimbabwe          Sub-Saharan Africa
#
# [241 rows x 2 columns]

# %% [markdown]
# -----------Fin de filtrage des faux pays dans le fichier Country-----------

# %% [markdown]
# ---------Filtrage des faux pays dans le fichier Country Séries--------

# %%
# lire le fichier csv

df_countrySeries = pd.read_csv('EdStatsCountry-Series.csv')
df_countrySeries.head(20)
# Out:
#    CountryCode         SeriesCode  \
# 0          ABW        SP.POP.TOTL
# 1          ABW        SP.POP.GROW
# 2          AFG        SP.POP.GROW
# 3          AFG  NY.GDP.PCAP.PP.CD
# 4          AFG        SP.POP.TOTL
# 5          AFG  NY.GDP.MKTP.PP.KD
# 6          AFG  NY.GNP.MKTP.PP.CD
# 7          AFG  NY.GDP.MKTP.PP.CD
# 8          AFG  NY.GDP.PCAP.PP.KD
# 9          AFG  NY.GNP.PCAP.PP.CD
# 10         AGO        SP.POP.TOTL
# 11         AGO        SP.POP.GROW
# 12         ALB        SP.POP.GROW
# 13         ALB        SP.POP.TOTL
# 14         AND        SP.POP.TOTL
# 15         AND        SP.POP.GROW
# 16         ARE        SP.POP.GROW
# 17         ARE        SP.POP.TOTL
# 18         ARG  NY.GDP.MKTP.PP.KD
# 19         ARG  NY.GNP.MKTP.PP.CD
#
#                                           DESCRIPTION  Unnamed: 3
# 0   Data sources : United Nations World Population...         NaN
# 1   Data sources: United Nations World Population ...         NaN
# ...

# %%
df_countrySeries=df_countrySeries.drop(columns=['Unnamed: 3'])
print(df_countrySeries)
# Out:
#     CountryCode         SeriesCode  \
# 0           ABW        SP.POP.TOTL
# 1           ABW        SP.POP.GROW
# 2           AFG        SP.POP.GROW
# 3           AFG  NY.GDP.PCAP.PP.CD
# 4           AFG        SP.POP.TOTL
# ..          ...                ...
# 608         ZAF        SP.POP.GROW
# 609         ZMB        SP.POP.GROW
# 610         ZMB        SP.POP.TOTL
# 611         ZWE        SP.POP.TOTL
# 612         ZWE        SP.POP.GROW
#
#                                            DESCRIPTION
# 0    Data sources : United Nations World Population...
# 1    Data sources: United Nations World Population ...
# 2    Data sources: United Nations World Population ...
# 3                   Estimates are based on regression.
# 4    Data sources : United Nations World Population...
# ..                                                 ...
# 608  Data sources : Statistics South Africa, United...
# 609  Data sources: United Nations World Population ...
# ...

# %%
df_countrySeries["CountryCode"].unique()
# Out:
# array(['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM',
#        'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA', 'BGD',
#        'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA',
#        'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHI', 'CHL',
#        'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI',
#        'CUB', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM',
#        'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI',
#        'FRA', 'FRO', 'FSM', 'GAB', 'GBR', 'GEO', 'GHA', 'GIB', 'GIN',
#        'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY',
#        'HKG', 'HND', 'HRV', 'HTI', 'HUN', 'IDN', 'IMN', 'IND', 'IRL',
#        'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN', 'KAZ',
#        'KEN', 'KGZ', 'KHM', 'KIR', 'KNA', 'KOR', 'KWT', 'LAO', 'LBN',
#        'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA',
# ...

# %%
countrySeries_to_remove=df_countrySeries[df_countrySeries["Unnamed: 3"].isna()]["CountryCode"]
country_to_remove
df_countrySeries[~df_countrySeries["CountryCode"].isin(countrySeries_to_remove)]

# %%
df_countrySeries["CountryCode"].unique()
# Out:
# array(['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM',
#        'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA', 'BGD',
#        'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA',
#        'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHI', 'CHL',
#        'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI',
#        'CUB', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM',
#        'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI',
#        'FRA', 'FRO', 'FSM', 'GAB', 'GBR', 'GEO', 'GHA', 'GIB', 'GIN',
#        'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY',
#        'HKG', 'HND', 'HRV', 'HTI', 'HUN', 'IDN', 'IMN', 'IND', 'IRL',
#        'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN', 'KAZ',
#        'KEN', 'KGZ', 'KHM', 'KIR', 'KNA', 'KOR', 'KWT', 'LAO', 'LBN',
#        'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA',
# ...

# %% [markdown]
# ----------------Fin de filtrage du fichier Country Séries---------------------

# %% [markdown]
# -------------Filtrage du fichier Foot Note----------------

# %%
# lire le fichier csv

df_FootNote = pd.read_csv('EdStatsFootNote.csv')
df_FootNote.head()
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN
# 4         ABW     SE.PRE.TCHR  YR2006  Country estimation.         NaN

# %%
df_FootNote["CountryCode"].unique()
# Out:
# array(['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG', 'ARM',
#        'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',
#        'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL',
#        'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHI',
#        'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV',
#        'CRI', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA',
#        'DNK', 'DOM', 'DZA', 'EAP', 'EAS', 'ECA', 'ECS', 'ECU', 'EGY',
#        'EMU', 'ERI', 'ESP', 'EST', 'ETH', 'EUU', 'FIN', 'FJI', 'FRA',
#        'FRO', 'FSM', 'GAB', 'GBR', 'GEO', 'GHA', 'GIB', 'GIN', 'GMB',
#        'GNB', 'GNQ', 'GRC', 'GRD', 'GTM', 'GUM', 'GUY', 'HIC', 'HKG',
#        'HND', 'HPC', 'HRV', 'HTI', 'HUN', 'IDN', 'IMN', 'IND', 'IRL',
#        'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN', 'KAZ',
#        'KEN', 'KGZ', 'KHM', 'KIR', 'KNA', 'KOR', 'KWT', 'LAC', 'LAO',
# ...

# %%
df_countrySeries=df_FootNote.drop(columns=['Unnamed: 4'])
print(df_FootNote)
# Out:
#        CountryCode      SeriesCode    Year  \
# 0              ABW  SE.PRE.ENRL.FE  YR2001
# 1              ABW  SE.TER.TCHR.FE  YR2005
# 2              ABW  SE.PRE.TCHR.FE  YR2000
# 3              ABW  SE.SEC.ENRL.GC  YR2004
# 4              ABW     SE.PRE.TCHR  YR2006
# ...            ...             ...     ...
# 643633         ZWE     SH.DYN.MORT  YR2007
# 643634         ZWE     SH.DYN.MORT  YR2014
# 643635         ZWE     SH.DYN.MORT  YR2015
# 643636         ZWE     SH.DYN.MORT  YR2017
# 643637         ZWE     SP.POP.GROW  YR2017
#
#                                    DESCRIPTION  Unnamed: 4
# 0                          Country estimation.         NaN
# 1                          Country estimation.         NaN
# 2                          Country estimation.         NaN
# 3                          Country estimation.         NaN
# 4                          Country estimation.         NaN
# ...                                        ...         ...
# ...

# %%
df_FootNote[["CountryCode","SeriesCode","Unnamed: 4"]]
# Out:
#        CountryCode      SeriesCode  Unnamed: 4
# 0              ABW  SE.PRE.ENRL.FE         NaN
# 1              ABW  SE.TER.TCHR.FE         NaN
# 2              ABW  SE.PRE.TCHR.FE         NaN
# 3              ABW  SE.SEC.ENRL.GC         NaN
# 4              ABW     SE.PRE.TCHR         NaN
# ...            ...             ...         ...
# 643633         ZWE     SH.DYN.MORT         NaN
# 643634         ZWE     SH.DYN.MORT         NaN
# 643635         ZWE     SH.DYN.MORT         NaN
# 643636         ZWE     SH.DYN.MORT         NaN
# 643637         ZWE     SP.POP.GROW         NaN
#
# [643638 rows x 3 columns]

# %%
#NETTOYAGE FOOT NOTE

foot_to_remove=df_FootNote[df_FootNote["Unnamed: 4"].isna()]["CountryCode"]
foot_to_remove
df_FootNote[~df_FootNote["CountryCode"].isin(foot_to_remove)]
# Out:
# Empty DataFrame
# Columns: [CountryCode, SeriesCode, Year, DESCRIPTION, Unnamed: 4]
# Index: []

# %%
# Nombre de lignes et de colonnes de la table foot note
nb_lignes, nb_colonnes = df_FootNote.shape
print("Nombre de lignes :", nb_lignes)
print("Nombre de colonnes :", nb_colonnes)
# Out:
# Nombre de lignes : 643638
# Nombre de colonnes : 5

# %%
# Nombre de lignes dupliquées de la table foot note
nb_doublons = df_FootNote.duplicated().sum()
print("Nombre de doublons :", nb_doublons)
# Out:
# Nombre de doublons : 0

# %%
# Proportion de valeurs manquantes par colonne de la table foot note
proportion_manquantes = df_FootNote.isna().mean()
print(proportion_manquantes)
# Out:
# CountryCode    0.0
# SeriesCode     0.0
# Year           0.0
# DESCRIPTION    0.0
# Unnamed: 4     1.0
# dtype: float64

# %%
# Statistiques descriptives de la table foot note
stats = df_FootNote.describe()
print(stats)
# Out:
#        Unnamed: 4
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# Nombre d'occurrences par valeur de la table foot note
occurrences = df_FootNote['CountryCode'].value_counts()
print(occurrences)
# Out:
# CountryCode
# LIC    7320
# CYP    7183
# LDC    6481
# SSA    6389
# SSF    6336
#        ...
# IMN      32
# CUW      23
# XKX      12
# MNP       4
# FRO       2
# Name: count, Length: 239, dtype: int64

# %% [markdown]
# -----------------Fin de filtrage du fichier Foot Note----------------

# %% [markdown]
# ---------------Filtrage du fichier Data----------------------

# %%
# lire le fichier csv data

df_data = pd.read_csv('EdStatsData.csv')
df_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  2060  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
data_to_remove=df_data[df_data["Country Name"].isna()][["2017","Unnamed: 69"]]
data_to_remove
df_data[~df_data["Country Code"].isin(data_to_remove)]
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# ...             ...          ...
# 886925     Zimbabwe          ZWE
# 886926     Zimbabwe          ZWE
# 886927     Zimbabwe          ZWE
# 886928     Zimbabwe          ZWE
# 886929     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 0       Adjusted net enrolment rate, lower secondary, ...
# 1       Adjusted net enrolment rate, lower secondary, ...
# 2       Adjusted net enrolment rate, lower secondary, ...
# 3       Adjusted net enrolment rate, lower secondary, ...
# 4       Adjusted net enrolment rate, primary, both sex...
# ...                                                   ...
# 886925  Youth illiterate population, 15-24 years, male...
# 886926  Youth literacy rate, population 15-24 years, b...
# ...

# %%
# Nombre de colonnes de la table data
nb_colonnes = len(df_data.columns)

print("Nombre de lignes :", nb_lignes)
print("Nombre de colonnes :", nb_colonnes)
# Out:
# Nombre de lignes : 643638
# Nombre de colonnes : 70

# %%
# Nombre de lignes dupliquées
nb_doublons = df_data.duplicated().sum()
print("Nombre de doublons :", nb_doublons)
# Out:
# Nombre de doublons : 0

# %%
# Proportion de valeurs manquantes par colonne
proportion_manquantes = df_data.isna().mean()
print(proportion_manquantes)
# Out:
# Country Name      0.000000
# Country Code      0.000000
# Indicator Name    0.000000
# Indicator Code    0.000000
# 1970              0.918496
#                     ...
# 2085              0.942007
# 2090              0.942007
# 2095              0.942007
# 2100              0.942007
# Unnamed: 69       1.000000
# Length: 70, dtype: float64

# %%
# Statistiques descriptives de la table data
stats = df_data.describe()
print(stats)
# Out:
#                1970          1971          1972          1973          1974  \
# count  7.228800e+04  3.553700e+04  3.561900e+04  3.554500e+04  3.573000e+04
# mean   1.974772e+09  4.253638e+09  4.592365e+09  5.105006e+09  5.401493e+09
# std    1.211687e+11  1.804814e+11  1.914083e+11  2.059170e+11  2.112150e+11
# min   -1.435564e+00 -1.594625e+00 -3.056522e+00 -4.032582e+00 -4.213563e+00
# 25%    8.900000e-01  8.853210e+00  9.240920e+00  9.595200e+00  9.861595e+00
# 50%    6.317724e+00  6.316240e+01  6.655139e+01  6.969595e+01  7.087760e+01
# 75%    6.251250e+01  5.655200e+04  5.863650e+04  6.202900e+04  6.383675e+04
# max    1.903929e+13  1.986457e+13  2.100916e+13  2.238367e+13  2.282991e+13
#
#                1975          1976          1977          1978          1979  \
# count  8.730600e+04  3.748300e+04  3.757400e+04  3.757600e+04  3.680900e+04
# mean   2.314288e+09  5.731808e+09  6.124437e+09  6.671489e+09  7.436724e+09
# ...

# %%
# Nombre d'occurrences par valeur
occurrences = df_data['Country Name'].value_counts()
print(occurrences)
# Out:
# Country Name
# Arab World                                     3665
# East Asia & Pacific                            3665
# East Asia & Pacific (excluding high income)    3665
# Euro area                                      3665
# Europe & Central Asia                          3665
#                                                ...
# Virgin Islands (U.S.)                          3665
# West Bank and Gaza                             3665
# Yemen, Rep.                                    3665
# Zambia                                         3665
# Zimbabwe                                       3665
# Name: count, Length: 242, dtype: int64

# %% [markdown]
# ----------------FIN ETAPE 3----------------------

# %% [markdown]
# ----------------------------------------------------------------------------

# %% [markdown]
# Exercice Partie 2 : Analysez des données de systèmes éducatifs

# %% [markdown]
# ----------------------------------------------------------------------------

# %% [markdown]
# --------------Fichier Séries-----------------

# %%
# chargement et affichage des données du fichier Séries
df_Series = pd.read_csv('EdStatsSeries.csv')
df_Series.head()
# Out:
#            Series Code       Topic  \
# 0  BAR.NOED.1519.FE.ZS  Attainment
# 1     BAR.NOED.1519.ZS  Attainment
# 2  BAR.NOED.15UP.FE.ZS  Attainment
# 3     BAR.NOED.15UP.ZS  Attainment
# 4  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     Short definition  \
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...
#
#                                      Long definition  Unit of measure  \
# ...

# %%
#Affichage de la colonne Topic du fichier Séries

df_Series["Topic"]
# Out:
# 0         Attainment
# 1         Attainment
# 2         Attainment
# 3         Attainment
# 4         Attainment
#             ...
# 3660    Expenditures
# 3661    Expenditures
# 3662    Expenditures
# 3663    Expenditures
# 3664    Expenditures
# Name: Topic, Length: 3665, dtype: object

# %%
# Affichage des valeurs uniques de la colonne Topic du fichier Séries

valeurs_uniques = df_Series['Topic'].unique()
print(valeurs_uniques)
# Out:
# ['Attainment' 'Education Equality' 'Infrastructure: Communications'
#  'Learning Outcomes'
#  'Economic Policy & Debt: National accounts: US$ at current prices: Aggregate indicators'
#  'Economic Policy & Debt: National accounts: US$ at constant 2010 prices: Aggregate indicators'
#  'Economic Policy & Debt: Purchasing power parity'
#  'Economic Policy & Debt: National accounts: Atlas GNI & GNI per capita'
#  'Teachers' 'Education Management Information Systems (SABER)'
#  'Early Child Development (SABER)' 'Engaging the Private Sector (SABER)'
#  'School Health and School Feeding (SABER)'
#  'School Autonomy and Accountability (SABER)' 'School Finance (SABER)'
#  'Student Assessment (SABER)' 'Teachers (SABER)'
#  'Tertiary Education (SABER)' 'Workforce Development (SABER)' 'Literacy'
#  'Background' 'Primary' 'Secondary' 'Tertiary' 'Early Childhood Education'
#  'Pre-Primary' 'Expenditures' 'Health: Risk factors' 'Health: Mortality'
# ...

# %%
#Valeurs à garder dans la colonne Topic

A_garder = ["Population","Infrastructure: Communications","Tertiary Education (SABER)",
            "School Finance (SABER)","Health: Population: Structure",
            "Economic Policy & Debt: National accounts: Atlas GNI & GNI per capita"]

# %%
#indicateur ou le topic n'est pas la

indicateur_a_supprimer=df_Series[~df_Series["Topic"].isin(A_garder)]["Series Code"].unique()
print(indicateur_a_supprimer)
# Out:
# ['BAR.NOED.1519.FE.ZS' 'BAR.NOED.1519.ZS' 'BAR.NOED.15UP.FE.ZS' ...
#  'UIS.XUNIT.USCONST.56.FSGOV' 'XGDP.23.FSGOV.FDINSTADM.FFD'
#  'XGDP.56.FSGOV.FDINSTADM.FFD']

# %%
df_Series.head()
# Out:
#            Series Code       Topic  \
# 0  BAR.NOED.1519.FE.ZS  Attainment
# 1     BAR.NOED.1519.ZS  Attainment
# 2  BAR.NOED.15UP.FE.ZS  Attainment
# 3     BAR.NOED.15UP.ZS  Attainment
# 4  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     Short definition  \
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...
#
#                                      Long definition  Unit of measure  \
# ...

# %% [markdown]
# --------------Fichier Data-----------------

# %%
# chargement et affichage des données
df_data = pd.read_csv('EdStatsData.csv')
df_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  2060  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# ...

# %%
df_data=df_data[~df_data["Indicator Name"].isin(indicateur_a_supprimer)]

# %%
df_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  2060  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
df_data=df_data[["Country Name","Country Code","Indicator Name","Indicator Code","1990","1995","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2013","2014","2015"]]

# %%
df_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1990      1995       2000       2001       2002       2003  ...  \
# 0        NaN       NaN        NaN        NaN        NaN        NaN  ...
# 1        NaN       NaN        NaN        NaN        NaN        NaN  ...
# 2        NaN       NaN        NaN        NaN        NaN        NaN  ...
# 3        NaN       NaN        NaN        NaN        NaN        NaN  ...
# ...

# %%
df_data=df_data[["Country Name","Country Code","Indicator Name","Indicator Code","2010","2011","2012"]]

# %%
df_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         2010      2011       2012
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4  85.211998  85.24514  86.101669

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   2010            242442 non-null  float64
#  5   2011            146012 non-null  float64
#  6   2012            147264 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 47.4+ MB

# %% [markdown]
# ---------------Etape 3 : Consolidez vos résultats dans un dataframe (pays, indicateurs)

# %%
import numpy as np

# %%
table_pivot = pd.pivot_table(df_data, index=["Country Name","Country Code","Indicator Name","Indicator Code"], aggfunc=np.mean)
table_pivot.head()
# Out:
# /tmp/ipython-input-151597958.py:1: FutureWarning: The provided callable <function mean at 0x793994b7c220> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   table_pivot = pd.pivot_table(df_data, index=["Country Name","Country Code","Indicator Name","Indicator Code"], aggfunc=np.mean)
#                                                                                                2010  \
# Country Name Country Code Indicator Name                                     Indicator Code
# Afghanistan  AFG          Adult illiterate population, 15+ years, % female   UIS.LPP.AG15T99    NaN
#                           Adult illiterate population, 15+ years, both se... UIS.LP.AG15T99     NaN
#                           Adult illiterate population, 15+ years, female ... UIS.LP.AG15T99.F   NaN
# ...

# %% [markdown]
# -----------------------------

# %% [markdown]
# Exercice Partie 3

# %% [markdown]
# -----------------------------------------------------------------------

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# Résultats attendus
#
# Un dataframe où une ligne correspond à un pays et une colonne à un indicateur. Seuls des indicateurs assez faiblement corrélés entre eux doivent être présents (moins de 70% en valeur absolue du coefficient de corrélation que vous choisissez).
# Code + Markdown pour reproduire les analyses des instructions ci-dessous

# %%
# matrice de corrélation entre Country Name et 2011

sns.scatterplot(x = 'Country Name', y='2011', data=df_data)
plt.title('Matrice de corrélation entre Country Name et 2010')
plt.show()

# %%
# matrice de corrélation entre Country Code et 2011

sns.scatterplot(x = 'Country Code', y='2011', data=df_data)
plt.title('Matrice de corrélation entre Country Code et 2011')
plt.show()

# %%
# matrice de corrélation entre Indicator Name et 2011

sns.scatterplot(x = 'Indicator Name', y='2011', data=df_data)
plt.title('Matrice de corrélation entre Indicator Name et 2011')
plt.show()

# %%
# matrice de corrélation entre Indicator Code et 2011

sns.scatterplot(x = 'Indicator Code', y='2011', data=df_data)
plt.title('Matrice de corrélation entre Indicator Code et 2011')
plt.show()

# %% [markdown]
# --------------END------------------

# %%
# !pip install poetry
